# %%
print("a c e")
# Out:
# a c e

# %%
print("7")

print("Erro: n1 e n2 não definidos na linha 1")

print("11")

print("Erro: variável com espaço na linha 1; atribuição inválida na linha 2")
# Out:
# 7
# Erro: n1 e n2 não definidos na linha 1
# 11

# %%
num1 = 6
num2 = 8
num3 = 10

media = (num1 + num2 + num3) / 3
print(media)
# Out:
# 8.0

# %%
velocidade_kmh = 90
velocidade_ms = velocidade_kmh / 3.6

print("Velocidade em km/h:", velocidade_kmh)
print("Velocidade em m/s:", velocidade_ms)
# Out:
# Velocidade em km/h: 90
# Velocidade em m/s: 25.0

# %%
nome = "Roney"

print("Meu nome é:")
print(nome)
# Out:
# Meu nome é:
# Roney
